# %%
import pandas as pd
import numpy as np

# %%
file_23 = pd.read_excel("20231.2_Prevalence_of_drug_use_in_the_general_population_including_NPS_national_data.xlsx")
file_22 = pd.read_excel("20221.2_-_Prevalence_of_drug_use_in_the_general_population_including_NPS_national_data.xlsx")
file_21 = pd.read_excel("2021.2_Prevalence_of_drug_use_in_the_general_population_including_NPS_-_national_data.xlsx")
file_20 = pd.read_excel("20201.2._Prevalence_of_drug_use_in_the_general_population_-_national_data.xls")

# %%
last_region = ""
for index in file_23.index:
    if not pd.isna(file_23.iloc[index, 1]):
        last_region = file_23.iloc[index, 1]
    else:
        file_23.iloc[index, 1] = last_region

# %%
file_23_renamed_column = file_23.rename({'CANNABIS': 'region'}, axis='columns')
europe = file_23_renamed_column[file_23_renamed_column["region"]=="Europe"]
europe_dropped = europe.iloc[:, 3:-5]
europe_dropped
# Out:
#                     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 181                    Belarus       1.07        0.9        1.3        NaN  \
# 182        Republic of Moldova        0.7        NaN        NaN        NaN
# 183        Republic of Moldova        0.9        NaN        NaN        NaN
# 184         Russian Federation       3.49       3.46       3.51        NaN
# 185                    Ukraine       2.13       1.29       2.98        NaN
# ..                         ...        ...        ...        ...        ...
# 376  United Kingdom (Scotland)        NaN        NaN        NaN        NaN
# 377  United Kingdom (Scotland)       6.29        NaN        NaN          9
# 378  United Kingdom (Scotland)        6.5        NaN        NaN        9.5
# 379  United Kingdom (Scotland)          7        NaN        NaN        NaN
# 380  United Kingdom (Scotland)        7.6        NaN        NaN        NaN
#
#     Unnamed: 8 Unnamed: 9
# 181        NaN       2007
# ...
